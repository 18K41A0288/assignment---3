# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %% [markdown]
# 1.	Read mobile dataset using pandas, and preprocess it (fill null values).

# %%
import pandas as pd 
import numpy as np
import io 
df = pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
print("total number of null values present in original file is : ",df.isnull().sum().sum())
df['sim_type']=df['sim_type'].fillna(df['sim_type'].mean())
df['aperture']=df['aperture'].fillna(df['aperture'].mean())
df['gpu_rank']=df['gpu_rank'].fillna(df['gpu_rank'].mean())
df['weight']=df['weight'].fillna(df['weight'].mean())
df['stand_by_time']=df['stand_by_time'].fillna(df['stand_by_time'].mean())
df['processor_frequency']=df['processor_frequency'].fillna(df['processor_frequency'].mean())
df['thickness']=df['thickness'].fillna(df['thickness'].mean())
df['flash_type']=df['flash_type'].fillna(df['flash_type'].mean())
df['front_camera_resolution']=df['front_camera_resolution'].fillna(df['front_camera_resolution'].mean())
df['auto_focus']=df['auto_focus'].fillna(df['auto_focus'].mean())
df['screen_size']=df['screen_size'].fillna(df['screen_size'].mean())
df['frames_per_second']=df['frames_per_second'].fillna(df['frames_per_second'].mean())
df['FM']=df['FM'].fillna(df['FM'].mean())
df['no_of_reviews_in_gsmarena_in_week']=df['no_of_reviews_in_gsmarena_in_week'].fillna(df['no_of_reviews_in_gsmarena_in_week'].mean())
df['phone_height']=df['phone_height'].fillna(df['phone_height'].mean())
df['screen_protection']=df['screen_protection'].fillna(df['screen_protection'].mean())
df['sim_size']=df['sim_size'].fillna(df['sim_size'].mean())
df['auto_focus']=df['auto_focus'].fillna(df['auto_focus'].mean())
df['phone_height']=df['phone_height'].fillna(df['phone_height'].mean())
df['talk_time']=df['talk_time'].fillna(df['talk_time'].mean())
df['video_resolution']=df['video_resolution'].fillna(df['video_resolution'].mean())
df['display_resolution']=df['display_resolution'].fillna(df['display_resolution'].mean())
df['removable_battery']=df['removable_battery'].fillna(df['removable_battery'].mean())
df['display_type']=df['display_type'].fillna(df['display_type'].mean())
df['primary_camera_resolution']=df['primary_camera_resolution'].fillna(df['primary_camera_resolution'].mean())
df['battery_type']=df['battery_type'].fillna(df['battery_type'].mean())
df['ram_memory']=df['ram_memory'].fillna(df['ram_memory'].mean())
df['internal_memory']=df['internal_memory'].fillna(df['internal_memory'].mean())
df['brand_rank']=df['brand_rank'].fillna(df['brand_rank'].mean())
df['no_of_cores']=df['no_of_cores'].fillna(df['no_of_cores'].mean())
df['micro_sd_slot']=df['micro_sd_slot'].fillna(df['micro_sd_slot'].mean())
df['screen_pixel_density']=df['screen_pixel_density'].fillna(df['screen_pixel_density'].mean())
df['water_proof_rate']=df['water_proof_rate'].fillna(df['water_proof_rate'].mean())
df['phone_width']=df['phone_width'].fillna(df['phone_width'].mean())
df['expandable_memory']=df['expandable_memory'].fillna(df['expandable_memory'].mean())
df['version']=df['version'].fillna(df['version'].mean())
df['usb_type']=df['usb_type'].fillna(df['usb_type'].mean())
df['battery_capacity']=df['battery_capacity'].fillna(df['battery_capacity'].mean())
df['processor_rank']=df['processor_rank'].fillna(df['processor_rank'].mean())
df['is_liked']=df['is_liked'].fillna(df['is_liked'].mean())
print("total number of null values present after replacing in file is : ",df.isnull().sum().sum())
df.to_csv('/content/drive/My Drive/mobile_cleaned.csv')
# Out:
# total number of null values present in original file is :  10
# total number of null values present after replacing in file is :  0

# %% [markdown]
# 2.	Draw correlation graph for mobile price with all attributes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
df = pd.read_csv('/content/drive/My Drive/mobile_cleaned.csv') 
d = pd.DataFrame(df,columns=['sim_type','aperture','gpu_rank','weight','stand_by_time','processor_frequency','thickness','flash_type','front_camera_resolution','auto_focus','screen_size','frames_per_second','FM','	no_of_reviews_in_gsmarena_in_week','os','phone_height','screen_protection','sim_size','price','talk_time','video_resolution','display_resolution','removable_battery','display_type','primary_camera_resolution','battery_type','ram_memory','internal_memory','brand_rank','no_of_cores','micro_sd_slot','screen_pixel_density','water_proof_rate','phone_width','expandable_memory','version','usb_type','battery_capacity','processor_rank','is_liked'])
p=list(d["price"])
l=list(d.columns)
for n in l :
   c=list(d[n])
   plt.xlabel(n)
   plt.ylabel("price")
   plt.plot(c,p,label=n)
   plt.scatter(c,p)
   plt.legend()
   plt.show()
corrMatrix = d.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 3.	Compute outer product of 2 vectors.
#
#
#
#
# Eg:
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
a=[[1,0],[0,1]]
b=[[1,2],[3,4]]
print('first matrix is  : ',a)
print('second matrix is : ',b)
print('outer product of the two matrix is\n',np.outer(a,b))
# Out:
# first matrix is  :  [[1, 0], [0, 1]]
# second matrix is :  [[1, 2], [3, 4]]
# outer product of the two matrix is
#  [[1 2 3 4]
#  [0 0 0 0]
#  [0 0 0 0]
#  [1 2 3 4]]

# %% [markdown]
# 4.	Write a NumPy program to compute the condition number of a given matrix..
#
# Original matrix:
#
# [[1 2]
#
# [3 4]]
#
# Condition number of the said matrix:
# 	14.9330343737

# %%
import numpy as np
g = np.array([[1,2],[3,4]])
print("Condition number of the said matrix : ",np.linalg.cond(g))
# Out:
# Condition number of the said matrix :  14.933034373659268

# %% [markdown]
# 5. write a NumPy program to compute the sum of the diagonal element of a given array(matrix).

# %%
import numpy as np
c=[1.9,6.3,3.1,7,4,2.9,9,5.3,8.4]
v = np.array(c)
v=np.reshape(v,(3,3))
print("Trace of the given matrix is : ",np.trace(v))
# Out:
# Trace of the given matrix is :  14.3
